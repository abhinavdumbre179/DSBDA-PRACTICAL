# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\comp
# [nltk_data]     492\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\comp
# [nltk_data]     492\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\comp
# [nltk_data]     492\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\comp 492\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
text= "Text is a cohesive unit of written, printed, or electronic language, forming the main body of content in documents, books, or digital messages. It consists of characters, symbols, or words that convey meaning, distinct from illustrations or formatting. Text can be analyzed, read, or transmitted through various digital mediums"

# %%
from nltk.tokenize import sent_tokenize
tokenized_text= sent_tokenize(text)
print(tokenized_text)
# Out:
# ['Text is a cohesive unit of written, printed, or electronic language, forming the main body of content in documents, books, or digital messages.', 'It consists of characters, symbols, or words that convey meaning, distinct from illustrations or formatting.', 'Text can be analyzed, read, or transmitted through various digital mediums']

# %%
from nltk.tokenize import word_tokenize
tokenized_word=word_tokenize(text)
print(tokenized_word)
# Out:
# ['Text', 'is', 'a', 'cohesive', 'unit', 'of', 'written', ',', 'printed', ',', 'or', 'electronic', 'language', ',', 'forming', 'the', 'main', 'body', 'of', 'content', 'in', 'documents', ',', 'books', ',', 'or', 'digital', 'messages', '.', 'It', 'consists', 'of', 'characters', ',', 'symbols', ',', 'or', 'words', 'that', 'convey', 'meaning', ',', 'distinct', 'from', 'illustrations', 'or', 'formatting', '.', 'Text', 'can', 'be', 'analyzed', ',', 'read', ',', 'or', 'transmitted', 'through', 'various', 'digital', 'mediums']

# %%
from nltk.corpus import stopwords
import re
stop_words=set(stopwords.words("english"))
print(stop_words)
text= "How to remove stop words with NLTK library in Python?"
text= re.sub('[^a-zA-Z]', ' ',text)
tokens = word_tokenize(text.lower())
filtered_text=[]
for w in tokens:
  if w not in stop_words:
    filtered_text.append(w)
print("Tokenized Sentence:",tokens)
print("Filterd Sentence:",filtered_text)
# Out:
# {'off', 'had', 'me', 'mightn', 'between', 'don', 'only', 'you', 'until', 'my', "that'll", "he's", 'them', 'should', "it's", 'for', "we'll", 'while', 'are', "hadn't", "mightn't", "should've", 'your', "she'll", 't', 'if', 'this', "they're", 'won', 'of', 'an', 'hasn', 'to', 'we', "couldn't", "haven't", 'needn', 'they', "hasn't", 'was', 'didn', 'she', 'ma', 'above', 'am', "didn't", 'll', 'o', 'does', "shouldn't", "i'll", 'its', 'before', 'haven', 'further', 'against', 'other', 'out', 'few', 'on', "she'd", 'too', "you'd", 'who', "i've", 'can', 'down', "i'd", "aren't", 'but', "we're", 'yourselves', 'than', 'their', 'when', 'as', 'ours', 'or', 'having', 'yourself', 'ourselves', 'has', 'wouldn', 'doing', 'very', "shan't", 'shan', 'that', 'how', 'all', 'those', 'through', 'weren', 'him', "won't", "they'd", 'hadn', 'and', 'just', 's', 'do', 'ain', 'by', "he'll", "isn't", 'during', 'hers', 'he', "wasn't", 'more', "you're", 'again', 'theirs', 'about', "needn't", "we've", 'will', 'aren', 'because
# ...

# %%
#Perform Stemming
from nltk.stem import PorterStemmer
e_words= ["get", "getter", "getest", "getting"]
ps =PorterStemmer()
for w in e_words:
  rootWord=ps.stem(w)
print(rootWord)
# Out:
# get

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
text = "running ran runs better best was are were is be"
tokenization = nltk.word_tokenize(text)
for w in tokenization:
  print("Lemma for {} is {}".format(w, wordnet_lemmatizer.lemmatize(w)))
# Out:
# Lemma for running is running
# Lemma for ran is ran
# Lemma for runs is run
# Lemma for better is better
# Lemma for best is best
# Lemma for was is wa
# Lemma for are is are
# Lemma for were is were
# Lemma for is is is
# Lemma for be is be

# %%
import nltk
from nltk.tokenize import word_tokenize
data="The world's most beautiful girl wears pink sweater fit her perfectly"
words=word_tokenize(data)
for word in words:
    print(nltk.pos_tag([word]))
# Out:
# [('The', 'DT')]
# [('world', 'NN')]
# [("'s", 'POS')]
# [('most', 'JJS')]
# [('beautiful', 'NN')]
# [('girl', 'NN')]
# [('wears', 'NNS')]
# [('pink', 'NN')]
# [('sweater', 'NN')]
# [('fit', 'NN')]
# [('her', 'PRP$')]
# [('perfectly', 'RB')]

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
documentA = 'My life is one of the best in the world '
documentB = 'She is the most beautiful girl in the world'

# %%
bagOfWordsA = documentA.split(' ')
bagOfWordsB = documentB.split(' ')

# %%
bagOfWordsA
# Out:
# ['My', 'life', 'is', 'one', 'of', 'the', 'best', 'in', 'the', 'world', '']

# %%
bagOfWordsB
# Out:
# ['She', 'is', 'the', 'most', 'beautiful', 'girl', 'in', 'the', 'world']

# %%
uniqueWords = set(bagOfWordsA).union(set(bagOfWordsB))

# %%
uniqueWords
# Out:
# {'',
#  'My',
#  'She',
#  'beautiful',
#  'best',
#  'girl',
#  'in',
#  'is',
#  'life',
#  'most',
#  'of',
#  'one',
#  'the',
#  'world'}

# %%
numOfWordsA = dict.fromkeys(uniqueWords, 0)
for word in bagOfWordsA:
  numOfWordsA[word] += 1
  numOfWordsB = dict.fromkeys(uniqueWords, 0)
for word in bagOfWordsB:
  numOfWordsB[word] += 1

# %%
numOfWordsA
# Out:
# {'': 1,
#  'She': 0,
#  'of': 1,
#  'best': 1,
#  'My': 1,
#  'in': 1,
#  'beautiful': 0,
#  'the': 2,
#  'life': 1,
#  'is': 1,
#  'one': 1,
#  'most': 0,
#  'world': 1,
#  'girl': 0}

# %%
numOfWordsB
# Out:
# {'': 0,
#  'She': 1,
#  'of': 0,
#  'best': 0,
#  'My': 0,
#  'in': 1,
#  'beautiful': 1,
#  'the': 2,
#  'life': 0,
#  'is': 1,
#  'one': 0,
#  'most': 1,
#  'world': 1,
#  'girl': 1}

# %%
def computeTF(wordDict, bagOfWords):
  tfDict = {}
  bagOfWordsCount = len(bagOfWords)
  for word, count in wordDict.items():
    tfDict[word] = count / float(bagOfWordsCount)
  return tfDict
tfA = computeTF(numOfWordsA, bagOfWordsA)
tfB = computeTF(numOfWordsB, bagOfWordsB)

# %%
tfA
# Out:
# {'': 0.09090909090909091,
#  'She': 0.0,
#  'of': 0.09090909090909091,
#  'best': 0.09090909090909091,
#  'My': 0.09090909090909091,
#  'in': 0.09090909090909091,
#  'beautiful': 0.0,
#  'the': 0.18181818181818182,
#  'life': 0.09090909090909091,
#  'is': 0.09090909090909091,
#  'one': 0.09090909090909091,
#  'most': 0.0,
#  'world': 0.09090909090909091,
#  'girl': 0.0}

# %%
tfB
# Out:
# {'': 0.0,
#  'She': 0.1111111111111111,
#  'of': 0.0,
#  'best': 0.0,
#  'My': 0.0,
#  'in': 0.1111111111111111,
#  'beautiful': 0.1111111111111111,
#  'the': 0.2222222222222222,
#  'life': 0.0,
#  'is': 0.1111111111111111,
#  'one': 0.0,
#  'most': 0.1111111111111111,
#  'world': 0.1111111111111111,
#  'girl': 0.1111111111111111}

# %%
def computeIDF(documents):
  import math
  N = len(documents)
  idfDict = dict.fromkeys(documents[0].keys(), 0)
  for document in documents:
    for word, val in document.items():
      if val > 0:
        idfDict[word] += 1
  for word, val in idfDict.items():
    idfDict[word] = math.log(N / float(val))
  return idfDict
idfs = computeIDF([numOfWordsA, numOfWordsB])
idfs
# Out:
# {'': 0.6931471805599453,
#  'She': 0.6931471805599453,
#  'of': 0.6931471805599453,
#  'best': 0.6931471805599453,
#  'My': 0.6931471805599453,
#  'in': 0.0,
#  'beautiful': 0.6931471805599453,
#  'the': 0.0,
#  'life': 0.6931471805599453,
#  'is': 0.0,
#  'one': 0.6931471805599453,
#  'most': 0.6931471805599453,
#  'world': 0.0,
#  'girl': 0.6931471805599453}

# %%
def computeTFIDF(tfBagOfWords, idfs):
  tfidf = {}
  for word, val in tfBagOfWords.items():
    tfidf[word] = val * idfs[word]
  return tfidf

tfidfA = computeTFIDF(tfA, idfs)
tfidfB = computeTFIDF(tfB, idfs)
df = pd.DataFrame([tfidfA, tfidfB])

# %%
tfidfA
# Out:
# {'': 0.06301338005090412,
#  'She': 0.0,
#  'of': 0.06301338005090412,
#  'best': 0.06301338005090412,
#  'My': 0.06301338005090412,
#  'in': 0.0,
#  'beautiful': 0.0,
#  'the': 0.0,
#  'life': 0.06301338005090412,
#  'is': 0.0,
#  'one': 0.06301338005090412,
#  'most': 0.0,
#  'world': 0.0,
#  'girl': 0.0}

# %%
tfidfB
# Out:
# {'': 0.0,
#  'She': 0.07701635339554948,
#  'of': 0.0,
#  'best': 0.0,
#  'My': 0.0,
#  'in': 0.0,
#  'beautiful': 0.07701635339554948,
#  'the': 0.0,
#  'life': 0.0,
#  'is': 0.0,
#  'one': 0.0,
#  'most': 0.07701635339554948,
#  'world': 0.0,
#  'girl': 0.07701635339554948}

# %%
df
# Out:
#                   She        of      best        My   in  beautiful  the  \
# 0  0.063013  0.000000  0.063013  0.063013  0.063013  0.0   0.000000  0.0
# 1  0.000000  0.077016  0.000000  0.000000  0.000000  0.0   0.077016  0.0
#
#        life   is       one      most  world      girl
# 0  0.063013  0.0  0.063013  0.000000    0.0  0.000000
# 1  0.000000  0.0  0.000000  0.077016    0.0  0.077016
